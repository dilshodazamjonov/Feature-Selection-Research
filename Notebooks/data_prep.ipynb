# %%
import pandas as pd


main_df = pd.read_csv('..\data\inputs\Master_Data_with_filtering_updated.csv')
main_df['EXT_SOURCE_2']
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\DILSHOD\AppData\Local\Temp\ipykernel_16724\3081849273.py:4: SyntaxWarning: invalid escape sequence '\d'
#   main_df = pd.read_csv('..\data\inputs\Master_Data_with_filtering_updated.csv')
# 0         0.262949
# 1         0.622246
# 2         0.555912
# 3         0.650442
# 4         0.322738
#             ...
# 307506    0.681632
# 307507    0.115992
# 307508    0.535722
# 307509    0.514163
# 307510    0.708569
# Name: EXT_SOURCE_2, Length: 307511, dtype: float64

# %%
main_df['TARGET'].value_counts()
# Out:
# TARGET
# 0    282686
# 1     24825
# Name: count, dtype: int64

# %%
24825 / (282686+24825 )
# Out:
# 0.08072881945686496

# %%
main_df[['EXT_SOURCE_2', 'EXT_SOURCE_3', 'TARGET']].corr(method='spearman')
# Out:
#               EXT_SOURCE_2  EXT_SOURCE_3    TARGET
# EXT_SOURCE_2      1.000000      0.106182 -0.147332
# EXT_SOURCE_3      0.106182      1.000000 -0.166330
# TARGET           -0.147332     -0.166330  1.000000
